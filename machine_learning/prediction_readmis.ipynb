# %% [markdown]
# # Projet La Capsule - Diabète
#
# Le but de ce NoteBook est de prédire, à l'aide d'algorithmes de Machine Learning et des données sur le diabète aux Etats-Unis entre 1999 et 2008, si un patient hospitalisé sera réadmis à l'hôpital sous 30 jours, et quels facteurs influences le plus la réadmission et la non-réadmission.
#
# Pour ce faire, nous utiliserons les données transformés par dbt, mises à disposition sur BigQuery.
#
# *Note importante* : la publication accompagnant les données ayant déjà mis en évidence la forte influence du test HbA1c (si le test est réalisé, le patient a moins de chance d'être réadmis) nous avons décidé de ne pas inclure cette feature dans notre modèle. Une raison complémentaire à cette exclusion est le fait que ce test soit très peu fréquemment réalisé sur la période étudié (moins de 17% des hospitalisations).

# %% [markdown]
# ## Imports
#
# Voici la liste des imports nécessaires au fonctionnement de ce NoteBook.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Création du DataFrame
#
# Pour créer le DataFrame, nous devons :
# - Télécharger les différentes tables du dataset "dbt_shared" du projet "projetdiabeteus" sur BigQuery
# - Fusionner la table de faits (hospitalisations) avec ses tables de dimensions
# - Sauvegarder le DataFrame complet ainsi créé
#
# Ces étapes sont réalisés par le script `creation_dataset.py`

# %% [markdown]
# ## Exploration des données

# %%
# Lecture des données
df = pd.read_csv(
    "/root/Trainings/La Capsule/Projet final/dbt/projectdiabeteus/machine_learning/data/diabetes.csv",
    keep_default_na = False) # On ne veut pas interpréter les valeurs NULL comme NA

# %% [markdown]
# Vérifions la taille des données

# %%
df.shape
# Out:
# (101766, 32)

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   hospitalisation_id            101766 non-null  int64
#  1   patient_id                    101766 non-null  int64
#  2   type_admission_id             101766 non-null  int64
#  3   sortie_id                     101766 non-null  int64
#  4   source_admission_id           101766 non-null  int64
#  5   specialite_id                 101766 non-null  int64
#  6   tranche_age                   101766 non-null  str
#  7   duree                         101766 non-null  int64
#  8   n_test_lab                    101766 non-null  int64
#  9   n_procedure                   101766 non-null  int64
#  10  n_medicament                  101766 non-null  int64
#  11  n_visite_externe              101766 non-null  int64
#  12  n_visite_urgence              101766 non-null  int64
#  13  n_visite_hopital              101766 non-null  int64
#  14  n_diag                        101766 non-null  int64
#  15  insulin                       101766 non-null  str
#  16  n_changement_posologie        101766 non-null  int64
#  17  readmis                       101766 non-null  int64
#  18  ethnie                        101766 non-null  str
#  19  genre                         101766 non-null  str
#  20  description_sortie            101766 non-null  str
#  21  categorie_sortie              101766 non-null  str
#  22  description_source_admission  101766 non-null  str
#  23  categorie_source_admission    101766 non-null  str
#  24  specialite                    101766 non-null  str
#  25  categorie_specialite          101766 non-null  str
#  26  description_1                 101766 non-null  str
#  27  description_2                 101766 non-null  str
#  28  description_3                 101766 non-null  str
#  29  categorie_1                   101766 non-null  str
#  30  categorie_2                   101766 non-null  str
#  31  categorie_3                   101766 non-null  str
# dtypes: int64(16), str(16)
# memory usage: 48.3 MB
# None

# %%
df.categorie_sortie.value_counts()
# Out:
# categorie_sortie
# Home                           73244
# Care Facility                  18474
# ?                               4680
# Hospital                        2297
# Expired/Deceased                1652
# Hospice                          771
# Left Against Medical Advice      623
# Outpatient                        25
# Name: count, dtype: int64
